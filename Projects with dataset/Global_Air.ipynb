# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load Dataset

# %%
df = pd.read_csv(r"C:\Users\ratho\Downloads\Global_Air_Pollution_Data_2025_2026.csv")

# %%
df
# Out:
#                    Date                City  Latitude  Longitude  PM2.5  \
# 0      19-10-2025 00:00    Lahore, Pakistan   31.5497    74.3436  115.9
# 1      19-10-2025 01:00    Lahore, Pakistan   31.5497    74.3436  119.2
# 2      19-10-2025 02:00    Lahore, Pakistan   31.5497    74.3436  120.6
# 3      19-10-2025 03:00    Lahore, Pakistan   31.5497    74.3436  120.1
# 4      19-10-2025 04:00    Lahore, Pakistan   31.5497    74.3436  118.7
# ...                 ...                 ...       ...        ...    ...
# 17467  17-01-2026 19:00  Jakarta, Indonesia   -6.2088   106.8456   53.2
# 17468  17-01-2026 20:00  Jakarta, Indonesia   -6.2088   106.8456   57.4
# 17469  17-01-2026 21:00  Jakarta, Indonesia   -6.2088   106.8456   69.2
# 17470  17-01-2026 22:00  Jakarta, Indonesia   -6.2088   106.8456   79.2
# 17471  17-01-2026 23:00  Jakarta, Indonesia   -6.2088   106.8456   77.8
#
#         PM10    NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  \
# ...

# %% [markdown]
# # PM2.5 --> Vehicle and industries
# # PM10 --> Road and Constructions
# # no2 --> Fuel Burning
# # so2 --> Coal, powerplant, Industries
# # co --> Incomplete fuel burning/ traffic
# # Ozone --> Ground level ozone - Sunlight + aemmision reaction

# %%
#float mein isliye rakhna chahiye q ki .ke baad ki value important hoti hia

# %%
df.head()
# Out:
#                Date              City  Latitude  Longitude  PM2.5   PM10  \
# 0  19-10-2025 00:00  Lahore, Pakistan   31.5497    74.3436  115.9  116.9
# 1  19-10-2025 01:00  Lahore, Pakistan   31.5497    74.3436  119.2  120.1
# 2  19-10-2025 02:00  Lahore, Pakistan   31.5497    74.3436  120.6  121.5
# 3  19-10-2025 03:00  Lahore, Pakistan   31.5497    74.3436  120.1  121.1
# 4  19-10-2025 04:00  Lahore, Pakistan   31.5497    74.3436  118.7  119.7
#
#      NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  AQI_Class
# 0  166.7  35.1  2668      0                   0.19  Unhealthy
# 1  160.4  34.3  2211      0                   0.20  Unhealthy
# 2  153.7  33.3  1818      0                   0.22  Unhealthy
# 3  148.0  32.5  1438      0                   0.24  Unhealthy
# 4  141.8  31.5  1122      0                   0.26  Unhealthy

# %%
df.tail()
# Out:
#                    Date                City  Latitude  Longitude  PM2.5  PM10  \
# 17467  17-01-2026 19:00  Jakarta, Indonesia   -6.2088   106.8456   53.2  53.3
# 17468  17-01-2026 20:00  Jakarta, Indonesia   -6.2088   106.8456   57.4  57.6
# 17469  17-01-2026 21:00  Jakarta, Indonesia   -6.2088   106.8456   69.2  69.4
# 17470  17-01-2026 22:00  Jakarta, Indonesia   -6.2088   106.8456   79.2  79.2
# 17471  17-01-2026 23:00  Jakarta, Indonesia   -6.2088   106.8456   77.8  78.0
#
#         NO2   SO2    CO  Ozone  Aerosol_Optical_Depth                AQI_Class
# 17467  80.9  47.1  3868     23                   0.68  Unhealthy for Sensitive
# 17468  85.2  52.2  3359     13                   0.57                Unhealthy
# 17469  83.5  57.2  2286     10                   0.51                Unhealthy
# 17470  80.1  59.0  1416      9                   0.50                Unhealthy
# 17471  75.5  55.4  1050      8                   0.52                Unhealthy

# %%
df.shape[0]
# Out:
# 17472

# %%
df.shape[1]
# Out:
# 12

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Latitude', 'Longitude', 'PM2.5', 'PM10', 'NO2', 'SO2',
#        'CO', 'Ozone', 'Aerosol_Optical_Depth', 'AQI_Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                      object
# City                      object
# Latitude                 float64
# Longitude                float64
# PM2.5                    float64
# PM10                     float64
# NO2                      float64
# SO2                      float64
# CO                         int64
# Ozone                      int64
# Aerosol_Optical_Depth    float64
# AQI_Class                 object
# dtype: object

# %%
#Find info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17472 entries, 0 to 17471
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   17472 non-null  object
#  1   City                   17472 non-null  object
#  2   Latitude               17472 non-null  float64
#  3   Longitude              17472 non-null  float64
#  4   PM2.5                  17472 non-null  float64
#  5   PM10                   17472 non-null  float64
#  6   NO2                    17472 non-null  float64
#  7   SO2                    17472 non-null  float64
#  8   CO                     17472 non-null  int64
#  9   Ozone                  17472 non-null  int64
#  10  Aerosol_Optical_Depth  17472 non-null  float64
#  11  AQI_Class              17472 non-null  object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# # for mathematical operation use ----->> Describe()

# %%
# describe function --> its calculate mathematical operations which is important for the data analyze and visualize
# describe function work only numeric columns
df.describe()
# Out:
#            Latitude     Longitude         PM2.5          PM10           NO2  \
# count  17472.000000  17472.000000  17472.000000  17472.000000  17472.000000
# mean      23.292375     43.056375     64.423644     69.654035     39.247299
# std       23.814690     68.421659     64.059167     67.748219     28.305581
# min      -23.550500    -74.006000      0.300000      0.400000      0.000000
# 25%       16.305525    -11.754175     12.600000     14.400000     17.200000
# 50%       30.081800     75.776300     44.600000     48.100000     32.300000
# 75%       40.106350     94.520775     97.100000    105.900000     54.725000
# max       51.507400    116.407400    430.300000    434.000000    205.100000
#
#                 SO2            CO         Ozone  Aerosol_Optical_Depth
# count  17472.000000  17472.000000  17472.000000           17472.000000
# mean      30.094351   1265.346440     56.203239               0.328928
# std       40.936636   1505.028461     52.169589               0.267045
# ...

# %%
df["AQI_Class"].unique()
# Out:
# array(['Unhealthy', 'Unhealthy for Sensitive', 'Moderate', 'Hazardous',
#        'Good'], dtype=object)

# %%
df["City"].unique()
# Out:
# array(['Lahore, Pakistan', 'Delhi, India', 'Beijing, China',
#        'New York, USA', 'London, UK', 'Dhaka, Bangladesh',
#        'Sao Paulo, Brazil', 'Jakarta, Indonesia'], dtype=object)

# %% [markdown]
# # check missing value

# %%
df.isnull()
# Out:
#         Date   City  Latitude  Longitude  PM2.5   PM10    NO2    SO2     CO  \
# 0      False  False     False      False  False  False  False  False  False
# 1      False  False     False      False  False  False  False  False  False
# 2      False  False     False      False  False  False  False  False  False
# 3      False  False     False      False  False  False  False  False  False
# 4      False  False     False      False  False  False  False  False  False
# ...      ...    ...       ...        ...    ...    ...    ...    ...    ...
# 17467  False  False     False      False  False  False  False  False  False
# 17468  False  False     False      False  False  False  False  False  False
# 17469  False  False     False      False  False  False  False  False  False
# 17470  False  False     False      False  False  False  False  False  False
# 17471  False  False     False      False  False  False  False  False  False
#
#        Ozone  Aerosol_Optical_Depth  AQI_Class
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# City                     0
# Latitude                 0
# Longitude                0
# PM2.5                    0
# PM10                     0
# NO2                      0
# SO2                      0
# CO                       0
# Ozone                    0
# Aerosol_Optical_Depth    0
# AQI_Class                0
# dtype: int64

# %% [markdown]
# # create numeric col dataframe

# %%
num_col = df[["PM2.5", "PM10", "NO2", "SO2", "CO", "Ozone", "Aerosol_Optical_Depth"]]

# %% [markdown]
# # check skewness

# %%
num_col.skew()
# Out:
# PM2.5                    1.440484
# PM10                     1.360389
# NO2                      1.182398
# SO2                      3.323606
# CO                       2.334214
# Ozone                    1.280040
# Aerosol_Optical_Depth    1.555039
# dtype: float64

# %% [markdown]
# # plot skewness

# %%
plt.hist(df["SO2"], bins = 10)
plt.xlabel("values")
plt.ylabel("frequency")
plt.title("histogram of skewness")
plt.show()

# %%
sns.kdeplot(df["SO2"], fill = True)
plt.title("KDE plot of SO2")
plt.show()

# %%
sns.kdeplot(df["CO"], fill = True)
plt.title("KDE plot of SO2")
plt.show()

# %% [markdown]
# # find duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Date                      object
# City                      object
# Latitude                 float64
# Longitude                float64
# PM2.5                    float64
# PM10                     float64
# NO2                      float64
# SO2                      float64
# CO                         int64
# Ozone                      int64
# Aerosol_Optical_Depth    float64
# AQI_Class                 object
# dtype: object

# %%
df
# Out:
#                    Date                City  Latitude  Longitude  PM2.5  \
# 0      19-10-2025 00:00    Lahore, Pakistan   31.5497    74.3436  115.9
# 1      19-10-2025 01:00    Lahore, Pakistan   31.5497    74.3436  119.2
# 2      19-10-2025 02:00    Lahore, Pakistan   31.5497    74.3436  120.6
# 3      19-10-2025 03:00    Lahore, Pakistan   31.5497    74.3436  120.1
# 4      19-10-2025 04:00    Lahore, Pakistan   31.5497    74.3436  118.7
# ...                 ...                 ...       ...        ...    ...
# 17467  17-01-2026 19:00  Jakarta, Indonesia   -6.2088   106.8456   53.2
# 17468  17-01-2026 20:00  Jakarta, Indonesia   -6.2088   106.8456   57.4
# 17469  17-01-2026 21:00  Jakarta, Indonesia   -6.2088   106.8456   69.2
# 17470  17-01-2026 22:00  Jakarta, Indonesia   -6.2088   106.8456   79.2
# 17471  17-01-2026 23:00  Jakarta, Indonesia   -6.2088   106.8456   77.8
#
#         PM10    NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  \
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_28716\936118274.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df
# Out:
#                      Date                City  Latitude  Longitude  PM2.5  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   31.5497    74.3436  115.9
# 1     2025-10-19 01:00:00    Lahore, Pakistan   31.5497    74.3436  119.2
# 2     2025-10-19 02:00:00    Lahore, Pakistan   31.5497    74.3436  120.6
# 3     2025-10-19 03:00:00    Lahore, Pakistan   31.5497    74.3436  120.1
# 4     2025-10-19 04:00:00    Lahore, Pakistan   31.5497    74.3436  118.7
# ...                   ...                 ...       ...        ...    ...
# 17467 2026-01-17 19:00:00  Jakarta, Indonesia   -6.2088   106.8456   53.2
# 17468 2026-01-17 20:00:00  Jakarta, Indonesia   -6.2088   106.8456   57.4
# 17469 2026-01-17 21:00:00  Jakarta, Indonesia   -6.2088   106.8456   69.2
# 17470 2026-01-17 22:00:00  Jakarta, Indonesia   -6.2088   106.8456   79.2
# 17471 2026-01-17 23:00:00  Jakarta, Indonesia   -6.2088   106.8456   77.8
#
#         PM10    NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  \
# ...

# %% [markdown]
# # slicing and Indexing

# %%
df.iloc[1778:,10]
# Out:
# 1778     1.08
# 1779     1.31
# 1780     1.57
# 1781     1.42
# 1782     1.34
#          ...
# 17467    0.68
# 17468    0.57
# 17469    0.51
# 17470    0.50
# 17471    0.52
# Name: Aerosol_Optical_Depth, Length: 15694, dtype: float64

# %%
df[df["Date"]=="2025-11-19 00:00:00"]
# Out:
#             Date                City  Latitude  Longitude  PM2.5   PM10  \
# 744   2025-11-19    Lahore, Pakistan   31.5497    74.3436  189.1  190.5
# 2928  2025-11-19        Delhi, India   28.6139    77.2090  169.0  170.4
# 5112  2025-11-19      Beijing, China   39.9042   116.4074   82.4   84.1
# 7296  2025-11-19       New York, USA   40.7128   -74.0060   16.1   16.1
# 9480  2025-11-19          London, UK   51.5074    -0.1278    7.3   10.1
# 11664 2025-11-19   Dhaka, Bangladesh   23.8103    90.4125   59.3   61.2
# 13848 2025-11-19   Sao Paulo, Brazil  -23.5505   -46.6333    5.6    5.6
# 16032 2025-11-19  Jakarta, Indonesia   -6.2088   106.8456  121.1  122.9
#
#          NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  AQI_Class
# 744    118.2  45.1  5539     12                   0.48  Hazardous
# 2928    90.9  54.9  2513     11                   0.42  Hazardous
# 5112    60.1  70.3  3372      3                   0.10  Unhealthy
# ...

# %%
df["Latitude"].unique()
# Out:
# array([ 31.5497,  28.6139,  39.9042,  40.7128,  51.5074,  23.8103,
#        -23.5505,  -6.2088])

# %%
df["Longitude"].unique()
# Out:
# array([ 74.3436,  77.209 , 116.4074, -74.006 ,  -0.1278,  90.4125,
#        -46.6333, 106.8456])

# %% [markdown]
# # use map function to convert latitude and longitude to places name

# %%
city_map = pd.DataFrame({
    "Latitude": [31.5497, 28.6139, 39.9042, 40.7128, 51.5074, 23.8103, -23.5505, -6.2088],
    "Longitude": [ 74.3436, 77.209 , 116.4074, -74.006 , -0.1278, 90.4125, -46.6333, 106.8456],
    "City": [
        "Lahore",
        "New Delhi",
        "Beijing",
        "New York",
        "London",
        "Dhaka",
        "Sao Paulo",
        "Jakarta"
    ]
}
)

# %%
on = df = df.merge(
    city_map,
    on=["Latitude", "Longitude"],
    how = "left"
    
)

# %%
df
# Out:
#                      Date              City_x  Latitude  Longitude  PM2.5  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   31.5497    74.3436  115.9
# 1     2025-10-19 01:00:00    Lahore, Pakistan   31.5497    74.3436  119.2
# 2     2025-10-19 02:00:00    Lahore, Pakistan   31.5497    74.3436  120.6
# 3     2025-10-19 03:00:00    Lahore, Pakistan   31.5497    74.3436  120.1
# 4     2025-10-19 04:00:00    Lahore, Pakistan   31.5497    74.3436  118.7
# ...                   ...                 ...       ...        ...    ...
# 17467 2026-01-17 19:00:00  Jakarta, Indonesia   -6.2088   106.8456   53.2
# 17468 2026-01-17 20:00:00  Jakarta, Indonesia   -6.2088   106.8456   57.4
# 17469 2026-01-17 21:00:00  Jakarta, Indonesia   -6.2088   106.8456   69.2
# 17470 2026-01-17 22:00:00  Jakarta, Indonesia   -6.2088   106.8456   79.2
# 17471 2026-01-17 23:00:00  Jakarta, Indonesia   -6.2088   106.8456   77.8
#
#         PM10    NO2   SO2    CO  Ozone  Aerosol_Optical_Depth  \
# ...

# %%
df["City_y"].unique()
# Out:
# array(['Lahore', 'New Delhi', 'Beijing', 'New York', 'London', 'Dhaka',
#        'Sao Paulo', 'Jakarta'], dtype=object)

# %%
df.drop(["Latitude","Longitude"], axis=1, inplace = True)
df
# Out:
#                      Date              City_x  PM2.5   PM10    NO2   SO2  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan  115.9  116.9  166.7  35.1
# 1     2025-10-19 01:00:00    Lahore, Pakistan  119.2  120.1  160.4  34.3
# 2     2025-10-19 02:00:00    Lahore, Pakistan  120.6  121.5  153.7  33.3
# 3     2025-10-19 03:00:00    Lahore, Pakistan  120.1  121.1  148.0  32.5
# 4     2025-10-19 04:00:00    Lahore, Pakistan  118.7  119.7  141.8  31.5
# ...                   ...                 ...    ...    ...    ...   ...
# 17467 2026-01-17 19:00:00  Jakarta, Indonesia   53.2   53.3   80.9  47.1
# 17468 2026-01-17 20:00:00  Jakarta, Indonesia   57.4   57.6   85.2  52.2
# 17469 2026-01-17 21:00:00  Jakarta, Indonesia   69.2   69.4   83.5  57.2
# 17470 2026-01-17 22:00:00  Jakarta, Indonesia   79.2   79.2   80.1  59.0
# 17471 2026-01-17 23:00:00  Jakarta, Indonesia   77.8   78.0   75.5  55.4
#
#          CO  Ozone  Aerosol_Optical_Depth                AQI_Class   City_y
# ...

# %% [markdown]
# # perfome data indexing according me

# %%
new_order = ["Date","City_x","City_y","PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth","AQI_Class"]
df = df[new_order]

# %%
df
# Out:
#                      Date              City_x   City_y  PM2.5   PM10    NO2  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   Lahore  115.9  116.9  166.7
# 1     2025-10-19 01:00:00    Lahore, Pakistan   Lahore  119.2  120.1  160.4
# 2     2025-10-19 02:00:00    Lahore, Pakistan   Lahore  120.6  121.5  153.7
# 3     2025-10-19 03:00:00    Lahore, Pakistan   Lahore  120.1  121.1  148.0
# 4     2025-10-19 04:00:00    Lahore, Pakistan   Lahore  118.7  119.7  141.8
# ...                   ...                 ...      ...    ...    ...    ...
# 17467 2026-01-17 19:00:00  Jakarta, Indonesia  Jakarta   53.2   53.3   80.9
# 17468 2026-01-17 20:00:00  Jakarta, Indonesia  Jakarta   57.4   57.6   85.2
# 17469 2026-01-17 21:00:00  Jakarta, Indonesia  Jakarta   69.2   69.4   83.5
# 17470 2026-01-17 22:00:00  Jakarta, Indonesia  Jakarta   79.2   79.2   80.1
# 17471 2026-01-17 23:00:00  Jakarta, Indonesia  Jakarta   77.8   78.0   75.5
#
# ...

# %% [markdown]
# # here data is break in month 10,11,12,01-2026

# %%
month_10_2025 = df[(df["Date"]>="205-10-19 00:00:00") & (df["Date"]<="2025-10-31 00:00:00")]
month_10_2025
# Out:
#                      Date              City_x   City_y  PM2.5   PM10    NO2  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   Lahore  115.9  116.9  166.7
# 1     2025-10-19 01:00:00    Lahore, Pakistan   Lahore  119.2  120.1  160.4
# 2     2025-10-19 02:00:00    Lahore, Pakistan   Lahore  120.6  121.5  153.7
# 3     2025-10-19 03:00:00    Lahore, Pakistan   Lahore  120.1  121.1  148.0
# 4     2025-10-19 04:00:00    Lahore, Pakistan   Lahore  118.7  119.7  141.8
# ...                   ...                 ...      ...    ...    ...    ...
# 15572 2025-10-30 20:00:00  Jakarta, Indonesia  Jakarta   97.8   99.9   97.7
# 15573 2025-10-30 21:00:00  Jakarta, Indonesia  Jakarta   96.4   98.0   87.5
# 15574 2025-10-30 22:00:00  Jakarta, Indonesia  Jakarta  102.0  103.6   77.9
# 15575 2025-10-30 23:00:00  Jakarta, Indonesia  Jakarta  112.5  113.9   69.9
# 15576 2025-10-31 00:00:00  Jakarta, Indonesia  Jakarta  113.4  114.6   62.5
#
# ...

# %%
month_11_2025= df[
    (df['Date'] >= pd.to_datetime("2025-11-01")) &
    (df['Date'] <= pd.to_datetime("2025-11-30"))
]
month_11_2025
# Out:
#                      Date              City_x   City_y  PM2.5   PM10    NO2  \
# 312   2025-11-01 00:00:00    Lahore, Pakistan   Lahore  149.9  156.9  103.0
# 313   2025-11-01 01:00:00    Lahore, Pakistan   Lahore  152.3  159.3  103.1
# 314   2025-11-01 02:00:00    Lahore, Pakistan   Lahore  151.8  159.3  100.9
# 315   2025-11-01 03:00:00    Lahore, Pakistan   Lahore  149.5  156.5   94.3
# 316   2025-11-01 04:00:00    Lahore, Pakistan   Lahore  145.8  152.7   85.5
# ...                   ...                 ...      ...    ...    ...    ...
# 16292 2025-11-29 20:00:00  Jakarta, Indonesia  Jakarta   90.1   91.0  103.1
# 16293 2025-11-29 21:00:00  Jakarta, Indonesia  Jakarta   94.3   95.2  100.3
# 16294 2025-11-29 22:00:00  Jakarta, Indonesia  Jakarta   98.5  100.1   96.4
# 16295 2025-11-29 23:00:00  Jakarta, Indonesia  Jakarta  102.4  104.5   91.2
# 16296 2025-11-30 00:00:00  Jakarta, Indonesia  Jakarta  105.9  107.8   84.9
#
# ...

# %%
month_12_2025 = df[(df["Date"]>="205-12-01 00:00:00") & (df["Date"]<="2025-12-31 00:00:00")]
month_12_2025
# Out:
#                      Date              City_x   City_y  PM2.5   PM10    NO2  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   Lahore  115.9  116.9  166.7
# 1     2025-10-19 01:00:00    Lahore, Pakistan   Lahore  119.2  120.1  160.4
# 2     2025-10-19 02:00:00    Lahore, Pakistan   Lahore  120.6  121.5  153.7
# 3     2025-10-19 03:00:00    Lahore, Pakistan   Lahore  120.1  121.1  148.0
# 4     2025-10-19 04:00:00    Lahore, Pakistan   Lahore  118.7  119.7  141.8
# ...                   ...                 ...      ...    ...    ...    ...
# 17036 2025-12-30 20:00:00  Jakarta, Indonesia  Jakarta  123.4  124.8   70.4
# 17037 2025-12-30 21:00:00  Jakarta, Indonesia  Jakarta  106.6  108.0   70.6
# 17038 2025-12-30 22:00:00  Jakarta, Indonesia  Jakarta   90.8   91.5   70.4
# 17039 2025-12-30 23:00:00  Jakarta, Indonesia  Jakarta   80.1   80.6   69.7
# 17040 2025-12-31 00:00:00  Jakarta, Indonesia  Jakarta   67.5   68.0   68.6
#
# ...

# %%
month_01_2026= df[(df["Date"]>="205-01-01 00:00:00") & (df["Date"]<="2026-01-31 00:00:00")]
month_01_2026
# Out:
#                      Date              City_x   City_y  PM2.5   PM10    NO2  \
# 0     2025-10-19 00:00:00    Lahore, Pakistan   Lahore  115.9  116.9  166.7
# 1     2025-10-19 01:00:00    Lahore, Pakistan   Lahore  119.2  120.1  160.4
# 2     2025-10-19 02:00:00    Lahore, Pakistan   Lahore  120.6  121.5  153.7
# 3     2025-10-19 03:00:00    Lahore, Pakistan   Lahore  120.1  121.1  148.0
# 4     2025-10-19 04:00:00    Lahore, Pakistan   Lahore  118.7  119.7  141.8
# ...                   ...                 ...      ...    ...    ...    ...
# 17467 2026-01-17 19:00:00  Jakarta, Indonesia  Jakarta   53.2   53.3   80.9
# 17468 2026-01-17 20:00:00  Jakarta, Indonesia  Jakarta   57.4   57.6   85.2
# 17469 2026-01-17 21:00:00  Jakarta, Indonesia  Jakarta   69.2   69.4   83.5
# 17470 2026-01-17 22:00:00  Jakarta, Indonesia  Jakarta   79.2   79.2   80.1
# 17471 2026-01-17 23:00:00  Jakarta, Indonesia  Jakarta   77.8   78.0   75.5
#
# ...

# %% [markdown]
# # check outlier of this data using boxplot

# %%
plt.figure(figsize=(11,6))
plt.boxplot(df[["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]])
plt.xticks(rotation = 90)
plt.title("Boxplot of numeric columns")
plt.show()

# %% [markdown]
# # corr matrix

# %%
corr = df[["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]].corr()

# %%
corr
# Out:
#                           PM2.5      PM10       NO2       SO2        CO  \
# PM2.5                  1.000000  0.965939  0.639710  0.718060  0.754097
# PM10                   0.965939  1.000000  0.612142  0.692222  0.710129
# NO2                    0.639710  0.612142  1.000000  0.441919  0.625372
# SO2                    0.718060  0.692222  0.441919  1.000000  0.648930
# CO                     0.754097  0.710129  0.625372  0.648930  1.000000
# Ozone                 -0.223137 -0.203732 -0.508219 -0.244529 -0.252294
# Aerosol_Optical_Depth  0.611105  0.604778  0.355935  0.377407  0.402010
#
#                           Ozone  Aerosol_Optical_Depth
# PM2.5                 -0.223137               0.611105
# PM10                  -0.203732               0.604778
# NO2                   -0.508219               0.355935
# SO2                   -0.244529               0.377407
# CO                    -0.252294               0.402010
# Ozone                  1.000000               0.152438
# ...

# %% [markdown]
# # heatmap corr of dataset

# %%
sns.heatmap(corr.round(2), annot = True)
# Out:
# <Axes: >

# %%
num_col
# Out:
#        PM2.5   PM10    NO2   SO2    CO  Ozone  Aerosol_Optical_Depth
# 0      115.9  116.9  166.7  35.1  2668      0                   0.19
# 1      119.2  120.1  160.4  34.3  2211      0                   0.20
# 2      120.6  121.5  153.7  33.3  1818      0                   0.22
# 3      120.1  121.1  148.0  32.5  1438      0                   0.24
# 4      118.7  119.7  141.8  31.5  1122      0                   0.26
# ...      ...    ...    ...   ...   ...    ...                    ...
# 17467   53.2   53.3   80.9  47.1  3868     23                   0.68
# 17468   57.4   57.6   85.2  52.2  3359     13                   0.57
# 17469   69.2   69.4   83.5  57.2  2286     10                   0.51
# 17470   79.2   79.2   80.1  59.0  1416      9                   0.50
# 17471   77.8   78.0   75.5  55.4  1050      8                   0.52
#
# [17472 rows x 7 columns]

# %% [markdown]
# # check density and skew of columns of dataset

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
          plt.figure(figsize=(10,6))
          sns.histplot(df[i],kde = True)
          plt.title(f"distribution of {i}")
          plt.show()

# %% [markdown]
# # make pairplot for learning realation between columns of the dataset

# %%
sns.pairplot(df,vars=["PM2.5","PM10","NO2"], hue = "AQI_Class")
plt.show()

# %%
sns.pairplot(df,vars=["SO2","CO","Ozone","Aerosol_Optical_Depth"], hue = "AQI_Class")
plt.show()

# %% [markdown]
# # make barplot for understanding city wise, country wise, target variables wise understandings with clear visuals

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
    plt.figure(figsize=(10,6))
    sns.barplot(x = "AQI_Class", y = i, data = df, hue = "AQI_Class")
    plt.title(f"{i} levels across AQI Class")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
    plt.figure(figsize=(10,6))
    sns.barplot(x = "AQI_Class", y = i, data = month_10_2025, hue = "City_y")
    plt.title(f"{i} levels across AQI Class month_10_25")
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
    plt.figure(figsize=(10,6))
    sns.barplot(x = "AQI_Class", y = i, data = month_11_2025, hue = "City_y")
    plt.title(f"{i} levels across AQI Class month_11_25")
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
    plt.figure(figsize=(10,6))
    sns.barplot(x = "AQI_Class", y = i, data = month_12_2025, hue = "City_y")
    plt.title(f"{i} levels across AQI Class month_12_25")
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

# %%
for i in ["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]:
    plt.figure(figsize=(10,6))
    sns.barplot(x = "AQI_Class", y = i, data = month_01_2026, hue = "City_y")
    plt.title(f"{i} levels across AQI Class month_01_26")
    plt.xticks(rotation = 90)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Conclusione --->

# %% [markdown]
# # In this project, air pollution data (2025–2026) was analyzed to understand pollution levels and major pollutants across different locations. Using Python, the data was cleaned and analyzed to find important patterns. The results showed that PM2.5 and PM10 are the main pollutants affecting air quality, mainly due to traffic, industries, and construction activities.
